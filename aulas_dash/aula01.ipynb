# %%
import pandas as pd
import plotly.express as px

# %%
# !pip install dash
# Out:
# ...
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#     --------------------------------------- 0.1/7.5 MB 1.5 MB/s eta 0:00:05
#    - -------------------------------------- 0.3/7.5 MB 2.2 MB/s eta 0:00:04
#    --- ------------------------------------ 0.6/7.5 MB 3.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.9/7.5 MB 4.0 MB/s eta 0:00:02
#    ------ --------------------------------- 1.1/7.5 MB 4.3 MB/s eta 0:00:02
#    ------- -------------------------------- 1.4/7.5 MB 4.6 MB/s eta 0:00:02
#    -------- ------------------------------- 1.7/7.5 MB 4.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.9/7.5 MB 4.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.2/7.5 MB 4.8 MB/s eta 0:00:02
#    ------------- -------------------------- 2.5/7.5 MB 5.0 MB/s eta 0:00:02
#    -------------- ------------------------- 2.8/7.5 MB 5.1 MB/s eta 0:00:01
# ...

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import datetime

# %%
df = pd.read_csv('C:/Users/Guilherme/OneDrive/Área de Trabalho/Pratices_DataScience/aulas_dash/data/sales_data_sample.csv', encoding='latin1')

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
#Transformar em datetime
df['Data_Pedido'] = pd.to_datetime(df['ORDERDATE'])
df['Ano'] = df['Data_Pedido'].dt.year
df['Mes'] = df['Data_Pedido'].dt.month_name()

#Deletar colunas que não serao usadas
drop_cols = ['ADDRESSLINE1', 'ADDRESSLINE2', 'POSTALCODE','CITY', 'TERRITORY', 'PHONE','STATE', 'CONTACTFIRSTNAME','CONTACTLASTNAME','CUSTOMERNAME','ORDERNUMBER']
df = df.drop(drop_cols,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 8
#       6 #Deletar colunas que não serao usadas
#       7 drop_cols = ['ADDRESSLINE1', 'ADDRESSLINE2', 'POSTALCODE','CITY', 'TERRITORY', 'PHONE','STATE', 'CONTACTFIRSTNAME','CONTACTLASTNAME','CUSTOMERNAME','ORDERNUMBER']
# ----> 8 df = df.drop(drop_cols,axis=1)
#
# File c:\Users\Guilherme\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
# ...

# %%
#Agrupar dados por pais
sales_by_country_series = df.groupby('COUNTRY')['SALES'].sum()
# Out:
# COUNTRY
# Australia       630623.10
# Austria         202062.53
# Belgium         108412.62
# Canada          224078.56
# Denmark         245637.15
# Finland         329581.91
# France         1110916.52
# Germany         220472.09
# Ireland          57756.43
# Italy           374674.31
# Japan           188167.81
# Norway          307463.70
# Philippines      94015.73
# Singapore       288488.41
# Spain          1215686.92
# Sweden          210014.21
# Switzerland     117713.56
# UK              478880.46
# USA            3627982.83
# Name: SALES, dtype: float64

# %% [markdown]
# __Iniciando a aplicação e dando nome a ela__

# %%
app = dash.Dash()#Iniciando aplicação
app.title = 'Dashboard'

# %%
app.layout = html.Div(
    html.Div([
        html.H1(children='Primeira Vizualização'),

        html.Div(children='''
            Dashboard de Vendas
        '''),

        dcc.Graph(
            id='vendas-por-pais',
            figure={
                'data': [
                    {'x': sales_by_country_series.index, 'y':sales_by_country_series.values , 'type': 'bar', 'name': 'VbyC'}
                ],
                'layout': {
                    'title': 'Vendas Por País [$]'
                }
            }
        ),

    ])
)

# %%
#Agrupando dados por ano
sales_by_year_series = df.groupby('Ano')['SALES'].sum()

# %%
app.layout = html.Div(
    html.Div([
        html.H1(children='Primeira Vizualização'),

        html.Div(children='''
            Dashboard de Vendas 
        '''),

        dcc.Graph(
            id='vendas-por-pais',
            figure={
                'data': [
                    {'x': sales_by_country_series.index, 'y':sales_by_country_series.values , 'type': 'bar', 'name': 'V-Por-P'}
                ],
                'layout': {
                    'title': 'Vendas Por País [$]',
                    'xaxis': dict(
                        title = 'Paises',
                        titlefont = dict(
                        family = 'Courier New, monospace',
                        size = 18,
                        colors='#7f7f7f'
                        )),
                    'yaxis' : dict(
                        title = 'Vendas [$]',
                        titlefont=dict(
                            family='Helvetica, monospace',
                            size=18,
                            colors='#7f7f7f'
                        ))
                }
            }
        ),

    dcc.Graph(
            id='grafico-2',
            figure={
                'data': [
                    {'x': sales_by_year_series.index, 'y':sales_by_year_series.values , 'type': 'bar', 'name': 'V-Por-P'},
                    {'x': sales_by_year_series.index, 'y':sales_by_year_series.values , 'type': 'line', 'name': 'V-Por-P'}
                ],
                'layout': {
                    'title': 'Vendas Por País [$]',
                    'xaxis': dict(
                        title = 'Paises',
                        titlefont = dict(
                        family = 'Courier New, monospace',
                        size = 18,
                        colors='#7f7f7f'
                        )),
                    'yaxis' : dict(
                        title = 'Vendas [$]',
                        titlefont=dict(
                            family='Helvetica, monospace',
                            size=18,
                            colors='#7f7f7f'
                        ))
                }
            }
        ),
    ])
)

# %% [markdown]
# __Iniciar o servidor da aplicação Dash__
# - __Parametros:__
#     - App.run_server() é um metodo fornecido pelo frameworck Dash para executar o servidor web para aplicação Dash
#     - debug = True habilita o modo de depuração automatica
#     - port = 8080, especifica a porta na qual o servidor ira fazer a requisição
#     - use_reloader = False, desabilita o carregamento automatico

# %%
if __name__ == '__main__':
    app.run_server(debug=True, port=8080, use_reloader=False)
