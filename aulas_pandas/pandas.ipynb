# %%
import pandas as pd

# %%
#lendo base de dados no formato .csv
#parametro sep é usado para definir qual o sepador entre os dados
#o parametro headerinforma em qual linha esta a coluna ou se ela nao existe
#se nao existir coluna (header = none) o pandas dara um numero para cada atributo da base
arquivo = 'kc_house_data.csv'
dataset = pd.read_csv(arquivo, sep=',', header = 0)

# %%
#imprimindo o tipo da varivel dataset
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
#dataframe é uma estrutura de dados onde linhas podem ter colunas de diferentes tipos

# %%
dataset.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
dataset = pd.read_csv(arquivo, sep=',',index_col='date')

# %%
#O parametro index_col informa a coluna na qual o dataframe sera indexada

# %%
dataset.head()
# Out:
#                          id     price  bedrooms  bathrooms  sqft_living  \
# date
# 20141013T000000  7129300520  221900.0         3       1.00         1180
# 20141209T000000  6414100192  538000.0         3       2.25         2570
# 20150225T000000  5631500400  180000.0         2       1.00          770
# 20141209T000000  2487200875  604000.0         4       3.00         1960
# 20150218T000000  1954400510  510000.0         3       2.00         1680
#
#                  sqft_lot  floors  waterfront  view  condition  grade  \
# date
# 20141013T000000      5650     1.0           0     0          3      7
# 20141209T000000      7242     2.0           0     0          3      7
# 20150225T000000     10000     1.0           0     0          3      6
# 20141209T000000      5000     1.0           0     0          5      7
# 20150218T000000      8080     1.0           0     0          3      8
#
#                  sqft_above  sqft_basement  yr_built  yr_renovated  zipcode  \
# date
# ...

# %%
dataset = pd.read_csv(arquivo, sep = ',',usecols=['id','date','price','bedrooms'])
dataset.head(100)
# Out:
#             id             date     price  bedrooms
# 0   7129300520  20141013T000000  221900.0         3
# 1   6414100192  20141209T000000  538000.0         3
# 2   5631500400  20150225T000000  180000.0         2
# 3   2487200875  20141209T000000  604000.0         4
# 4   1954400510  20150218T000000  510000.0         3
# ..         ...              ...       ...       ...
# 95  1483300570  20140908T000000  905000.0         4
# 96  3422049190  20150330T000000  247500.0         3
# 97  1099611230  20140912T000000  199000.0         4
# 98   722079104  20140711T000000  314000.0         3
# 99  7338200240  20140516T000000  437500.0         3
#
# [100 rows x 4 columns]

# %%
dataset.head(20)
# Out:
#             id             date      price  bedrooms
# 0   7129300520  20141013T000000   221900.0         3
# 1   6414100192  20141209T000000   538000.0         3
# 2   5631500400  20150225T000000   180000.0         2
# 3   2487200875  20141209T000000   604000.0         4
# 4   1954400510  20150218T000000   510000.0         3
# 5   7237550310  20140512T000000  1225000.0         4
# 6   1321400060  20140627T000000   257500.0         3
# 7   2008000270  20150115T000000   291850.0         3
# 8   2414600126  20150415T000000   229500.0         3
# 9   3793500160  20150312T000000   323000.0         3
# 10  1736800520  20150403T000000   662500.0         3
# 11  9212900260  20140527T000000   468000.0         2
# 12   114101516  20140528T000000   310000.0         3
# 13  6054650070  20141007T000000   400000.0         3
# 14  1175000570  20150312T000000   530000.0         5
# 15  9297300055  20150124T000000   650000.0         4
# 16  1875500060  20140731T000000   395000.0         3
# ...

# %%
dataset.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms'], dtype='object')

# %%
dataset.count()
# Out:
# id          21613
# date        21613
# price       21613
# bedrooms    21613
# dtype: int64

# %%
dataset.describe()
#metodo describe() exibe informações estatisticas da base de dados
#Varias informações como desvio padrao media, valor minimo e valor maximo de colunas
# Out:
#                  id         price      bedrooms
# count  2.161300e+04  2.161300e+04  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842
# std    2.876566e+09  3.671272e+05      0.930062
# min    1.000102e+06  7.500000e+04      0.000000
# 25%    2.123049e+09  3.219500e+05      3.000000
# 50%    3.904930e+09  4.500000e+05      3.000000
# 75%    7.308900e+09  6.450000e+05      4.000000
# max    9.900000e+09  7.700000e+06     33.000000

# %%
dataset.tail()#imprime as 5 ultimas linhas
# Out:
#                id             date     price  bedrooms
# 21608   263000018  20140521T000000  360000.0         3
# 21609  6600060120  20150223T000000  400000.0         4
# 21610  1523300141  20140623T000000  402101.0         2
# 21611   291310100  20150116T000000  400000.0         3
# 21612  1523300157  20141015T000000  325000.0         2

# %%
#Metodo sample() imprime 1 linhas aleatorias do dataset
dataset.sample(5)
# Out:
#                id             date     price  bedrooms
# 13454  6791100410  20140919T000000  432000.0         3
# 1864   2143700830  20141006T000000  207000.0         4
# 17029  1150700130  20150421T000000  275000.0         3
# 2460   7640400106  20140911T000000  438400.0         2
# 18027  3300701185  20140925T000000  500000.0         2

# %%
#Metodo shape retorna em formato de tupla a quantidade de linhas e colunas do dataset
dataset.shape
# Out:
# (21613, 4)

# %%
#metodo info() imprime infomações sobre as colunas e uso de memoria
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        21613 non-null  int64
#  1   date      21613 non-null  object
#  2   price     21613 non-null  float64
#  3   bedrooms  21613 non-null  int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 675.5+ KB

# %% [markdown]
# # Trabalhando com grandes arquivos
# - Gerenciar memoria
# - Diversidade de arquivos
# - Sobrecarga de servidor
